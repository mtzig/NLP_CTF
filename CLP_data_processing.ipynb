# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import random
import re

# %%
train_df = pd.read_csv("./data/train_df.csv")
identities = [ident[0] for ident in pd.read_csv("./data/adjectives_people.txt", header=None).values.tolist()]

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'comment_text', 'toxic', 'gay', 'bisexual',
#        'transgender', 'trans', 'queer', 'lgbt', 'lgbtq', 'homosexual',
#        'straight', 'heterosexual', 'male', 'female', 'nonbinary', 'african',
#        'african american', 'black', 'white', 'european', 'hispanic', 'latino',
#        'latina', 'latinx', 'mexican', 'canadian', 'american', 'asian',
#        'indian', 'middle eastern', 'chinese', 'japanese', 'christian',
#        'muslim', 'jewish', 'buddhist', 'catholic', 'protestant', 'sikh',
#        'taoist', 'old', 'older', 'young', 'younger', 'teenage', 'millenial',
#        'middle aged', 'elderly', 'blind', 'deaf', 'paralyzed', 'lesbian'],
#       dtype='object')

# %%
index = []
toxic = []
comment_text = []
index_count = 0
a = []

for row_index in tqdm(range(len(train_df))):
    comment_words = train_df.iloc[row_index]['comment_text'].split()
    if len(set(identities).intersection(comment_words)) != 0: #Does contain identity
        index.append(index_count)
        index_count += 1
        ident = str(set(identities).intersection(comment_words).pop())
        #Append perturbed sentences to a (not including original sentence)
        a.append([re.sub(r'\b' + re.escape(ident) + r'\b', replace_ident, train_df.at[row_index, "comment_text"], flags=re.IGNORECASE) for replace_ident in identities if replace_ident != ident])
    else:
        index.append(-1)
    toxic.append(round(train_df.iloc[row_index]["toxic"]))
    comment_text.append(train_df.iloc[row_index]["comment_text"])
# Out:
# 100%|██████████| 159571/159571 [00:58<00:00, 2723.38it/s]

# %%
data_tuples = list(zip(comment_text, toxic, index))

# %%
CLP_df1 = pd.DataFrame(data_tuples, columns=["comment_text", "toxic", "index"])

# %%
CLP_df1[:40]
# Out:
#                                          comment_text  toxic  index
# 0   Explanation\nWhy the edits made under my usern...      0     -1
# 1   D'aww! He matches this background colour I'm s...      0     -1
# 2   Hey man, I'm really not trying to edit war. It...      0     -1
# 3   "\nMore\nI can't make any real suggestions on ...      0     -1
# 4   You, sir, are my hero. Any chance you remember...      0     -1
# 5   "\n\nCongratulations from me as well, use the ...      0     -1
# 6        COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK      1     -1
# 7   Your vandalism to the Matt Shirvington article...      0     -1
# 8   Sorry if the word 'nonsense' was offensive to ...      0     -1
# 9   alignment on this subject and which are contra...      0     -1
# 10  "\nFair use rationale for Image:Wonju.jpg\n\nT...      0     -1
# 11  bbq \n\nbe a man and lets discuss it-maybe ove...      0     -1
# 12  Hey... what is it..\n@ | talk .\nWhat is it......      1     -1
# 13  Before you start throwing accusations and warn...      0     -1
# 14  Oh, and the girl above started her arguments w...      0     -1
# 15  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...      0      0
# 16  Bye! \n\nDon't look, come or think of comming ...      1     -1
# 17   REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski      0     -1
# 18  The Mitsurugi point made no sense - why not ar...      0     -1
# 19  Don't mean to bother you \n\nI see that you're...      0     -1
# 20  "\n\n Regarding your recent edits \n\nOnce aga...      0     -1
# 21  "\nGood to know. About me, yeah, I'm studying ...      0     -1
# 22  "\n\n Snowflakes are NOT always symmetrical! \...      0     -1
# 23  "\n\n The Signpost: 24 September 2012 \n\n Rea...      0     -1
# 24  "\n\nRe-considering 1st paragraph edit?\nI don...      0     -1
# 25  Radial symmetry \n\nSeveral now extinct lineag...      0     -1
# 26  There's no need to apologize. A Wikipedia arti...      0     -1
# 27  Yes, because the mother of the child in the ca...      0     -1
# 28  "\nOk. But it will take a bit of work but I ca...      0     -1
# 29  "== A barnstar for you! ==\n\n  The Real Life ...      0     -1
# 30  How could I post before the block expires?  Th...      0     -1
# 31  Not sure about a heading of 'Fight for Freedom...      0     -1
# 32  Praise \n\nlooked at this article about 6 mont...      0     -1
# 33  I was able to post the above list so quickly b...      0     -1
# 34  "\nWell, not ""before the process"" but ""befo...      0     -1
# 35  "\n\nNot at all, you are making a straw man ar...      0     -1
# 36  "\n\n ""Mainland Asia"" includes ""the lower b...      0     -1
# 37  pretty much everyone from warren county/surrou...      0     -1
# 38  Hi Explicit, can you block O Fenian for edit-w...      0     -1
# 39  Notability of Rurika Kasuga\nA tag has been pl...      0     -1

# %%
indices = []
orig_text = []
aug_text = []

for row_index in tqdm(range(len(CLP_df1))):
    if CLP_df1.iloc[row_index]['index'] != -1:
        indices.append(CLP_df1.iloc[row_index]['index'])
        orig_text.append(CLP_df1.iloc[row_index]['comment_text'])
        comment_words = CLP_df1.iloc[row_index]['comment_text'].split()
        ident = str(set(identities).intersection(comment_words).pop())
        aug_text.append([re.sub(r'\b' + re.escape(ident) + r'\b', replace_ident, CLP_df1.at[row_index, "comment_text"], flags=re.IGNORECASE) for replace_ident in identities if replace_ident != ident])
# Out:
# 100%|██████████| 159571/159571 [00:22<00:00, 7170.67it/s]

# %%
data_tuples = list(zip(indices, orig_text))
CLP_df2 = pd.DataFrame(data_tuples, columns=["index", "orig_text"])

# %%
aug_text_df_raw = pd.DataFrame(list(zip(*aug_text)))
aug_text_df = aug_text_df_raw.T
CLP_df3 = pd.concat([CLP_df2, aug_text_df], axis = 1)

# %%
CLP_df3[:10]
# Out:
#    index                                          orig_text  \
# 0      0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1      1  You are gay or antisemmitian? \n\nArchangel WH...
# 2      2  My Band Page's deletion. You thought I was gon...
# 3      3  A Bisexual, like a homosexual or a heterosexua...
# 4      4  I went there around the same time he did, and ...
# 5      5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6      6  "== Attributing and classifying of personaliti...
# 7      7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8      8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9      9  u r a tw@ fuck off u gay boy.U r smelly.Fuck u...
#
#                                                    0  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are lesbian or antisemmitian? \n\nArchange...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a lesbian or a heterosexual, ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u lesbian boy.U r smelly.Fu...
#
#                                                    1  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are bisexual or antisemmitian? \n\nArchang...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a gay or a heterosexual, is n...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u bisexual boy.U r smelly.F...
#
#                                                    2  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are transgender or antisemmitian? \n\nArch...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a bisexual or a heterosexual,...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u transgender boy.U r smell...
#
#                                                    3  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are trans or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a transgender or a heterosexu...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u trans boy.U r smelly.Fuck...
#
#                                                    4  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are queer or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a trans or a heterosexual, is...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u queer boy.U r smelly.Fuck...
#
#                                                    5  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are lgbt or antisemmitian? \n\nArchangel W...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a queer or a heterosexual, is...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u lgbt boy.U r smelly.Fuck ...
#
#                                                    6  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are lgbtq or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a lgbt or a heterosexual, is ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u lgbtq boy.U r smelly.Fuck...
#
#                                                    7  ...  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...  ...
# 1  You are homosexual or antisemmitian? \n\nArcha...  ...
# 2  My Band Page's deletion. You thought I was gon...  ...
# 3  A Bisexual, like a lgbtq or a heterosexual, is...  ...
# 4  I went there around the same time he did, and ...  ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...  ...
# 6  "== Attributing and classifying of personaliti...  ...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...  ...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...  ...
# 9  u r a tw@ fuck off u homosexual boy.U r smelly...  ...
#
#                                                   39  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are older or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a older or a heterosexual, is...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u older boy.U r smelly.Fuck...
#
#                                                   40  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are young or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a young or a heterosexual, is...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u young boy.U r smelly.Fuck...
#
#                                                   41  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are younger or antisemmitian? \n\nArchange...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a younger or a heterosexual, ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u younger boy.U r smelly.Fu...
#
#                                                   42  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are teenage or antisemmitian? \n\nArchange...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a teenage or a heterosexual, ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u teenage boy.U r smelly.Fu...
#
#                                                   43  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are millenial or antisemmitian? \n\nArchan...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a millenial or a heterosexual...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u millenial boy.U r smelly....
#
#                                                   44  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are middle aged or antisemmitian? \n\nArch...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a middle aged or a heterosexu...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u middle aged boy.U r smell...
#
#                                                   45  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are elderly or antisemmitian? \n\nArchange...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a elderly or a heterosexual, ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u elderly boy.U r smelly.Fu...
#
#                                                   46  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are blind or antisemmitian? \n\nArchangel ...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a blind or a heterosexual, is...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u blind boy.U r smelly.Fuck...
#
#                                                   47  \
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are deaf or antisemmitian? \n\nArchangel W...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a deaf or a heterosexual, is ...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u deaf boy.U r smelly.Fuck ...
#
#                                                   48
# 0  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...
# 1  You are paralyzed or antisemmitian? \n\nArchan...
# 2  My Band Page's deletion. You thought I was gon...
# 3  A Bisexual, like a paralyzed or a heterosexual...
# 4  I went there around the same time he did, and ...
# 5  Ahh, Hello Witzeman \n\n203.92.84.161  \nSymbo...
# 6  "== Attributing and classifying of personaliti...
# 7  Hi \n\nHi, good day.\n\nMy deepest apologies t...
# 8  REPLY ABOVE:\nThat was me, loser. The UN defin...
# 9  u r a tw@ fuck off u paralyzed boy.U r smelly....
#
# [10 rows x 51 columns]
