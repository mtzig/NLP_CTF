# %%
# %cd ..
# Out:
# /Users/teaganjohnson/Desktop/NLP_CTF

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import random

# %%
# civil_df = pd.read_csv("./data/civil_comments.csv")
synthetic_data = pd.read_csv("./data/bias_madlibs_89k.csv")
# train_identities_df = pd.read_csv("./data/test_identities.txt", header=None)
# train_identities_lists = train_identities_df.values.tolist()
test_identities_df = pd.read_csv("./data/test_identities.txt", header=None)
test_identities_list = test_identities_df.values.tolist()

# %%
test_identities = []
for ident in test_identities_list:
    test_identities.append(ident[0])
#train_identities

# %%
sentences = []
a = []
toxicity = []

for row_index in tqdm(range(len(synthetic_data))):
    comment_text = synthetic_data.iloc[row_index]['Text'].split()
    if synthetic_data.iloc[row_index]['Label'] == "NOT_BAD" and len(set(test_identities).intersection(comment_text)) != 0:
        identity = str(set(test_identities).intersection(comment_text).pop())
        sentences.append(synthetic_data.iloc[row_index]['Text'])
        toxicity.append(0)
        cur_a = []
        
        for diff_identity in test_identities:
            cur_a.append(synthetic_data.at[row_index, "Text"].replace(identity, diff_identity))
        a.append(cur_a)
# print(sentences)
# print(toxicity)
# print(a)
# Out:
# 100%|██████████| 89483/89483 [00:14<00:00, 6010.23it/s]

# %%
synthetic_raw = pd.DataFrame(list(zip(*a)))
synthetic_df = synthetic_raw.T

synthetic_df.insert(0, column='comment_text', value=sentences)

synthetic_df
# Out:
#                                             comment_text  \
# 0           paralyzed people are just like everyone else
# 1               black people are just like everyone else
# 2              latina people are just like everyone else
# 3                 old people are just like everyone else
# 4          homosexual people are just like everyone else
# ...                                                  ...
# 11473  Myesha is paralyzed and is a happy factory worker
# 11474               Abdul is old and is a fun programmer
# 11475     Hiro is black and is a friendly police officer
# 11476         Ling is paralyzed and is a friendly doctor
# 11477  Alva is african american and is a wonderful ha...
#
#                                                        0  \
# 0      african american people are just like everyone...
# 1      african american people are just like everyone...
# 2      african american people are just like everyone...
# 3      african american people are just like everyone...
# 4      african american people are just like everyone...
# ...                                                  ...
# 11473  Myesha is african american and is a happy fact...
# 11474  Abdul is african american and is a fun programmer
# 11475  Hiro is african american and is a friendly pol...
# 11476  Ling is african american and is a friendly doctor
# 11477  Alva is african african american and is a wond...
#
#                                                        1  \
# 0         middle aged people are just like everyone else
# 1         middle aged people are just like everyone else
# 2         middle aged people are just like everyone else
# 3         middle aged people are just like everyone else
# 4         middle aged people are just like everyone else
# ...                                                  ...
# 11473  Myesha is middle aged and is a happy factory w...
# 11474       Abdul is middle aged and is a fun programmer
# 11475  Hiro is middle aged and is a friendly police o...
# 11476       Ling is middle aged and is a friendly doctor
# 11477  Alva is african middle aged and is a wonderful...
#
#                                                        2  \
# 0      middle eastern people are just like everyone else
# 1      middle eastern people are just like everyone else
# 2      middle eastern people are just like everyone else
# 3      middle eastern people are just like everyone else
# 4      middle eastern people are just like everyone else
# ...                                                  ...
# 11473  Myesha is middle eastern and is a happy factor...
# 11474    Abdul is middle eastern and is a fun programmer
# 11475  Hiro is middle eastern and is a friendly polic...
# 11476    Ling is middle eastern and is a friendly doctor
# 11477  Alva is african middle eastern and is a wonder...
#
#                                                        3  \
# 0           paralyzed people are just like everyone else
# 1           paralyzed people are just like everyone else
# 2           paralyzed people are just like everyone else
# 3           paralyzed people are just like everyone else
# 4           paralyzed people are just like everyone else
# ...                                                  ...
# 11473  Myesha is paralyzed and is a happy factory worker
# 11474         Abdul is paralyzed and is a fun programmer
# 11475  Hiro is paralyzed and is a friendly police off...
# 11476         Ling is paralyzed and is a friendly doctor
# 11477  Alva is african paralyzed and is a wonderful h...
#
#                                                        4  \
# 0          protestant people are just like everyone else
# 1          protestant people are just like everyone else
# 2          protestant people are just like everyone else
# 3          protestant people are just like everyone else
# 4          protestant people are just like everyone else
# ...                                                  ...
# 11473  Myesha is protestant and is a happy factory wo...
# 11474        Abdul is protestant and is a fun programmer
# 11475  Hiro is protestant and is a friendly police of...
# 11476        Ling is protestant and is a friendly doctor
# 11477  Alva is african protestant and is a wonderful ...
#
#                                                        5  \
# 0          homosexual people are just like everyone else
# 1          homosexual people are just like everyone else
# 2          homosexual people are just like everyone else
# 3          homosexual people are just like everyone else
# 4          homosexual people are just like everyone else
# ...                                                  ...
# 11473  Myesha is homosexual and is a happy factory wo...
# 11474        Abdul is homosexual and is a fun programmer
# 11475  Hiro is homosexual and is a friendly police of...
# 11476        Ling is homosexual and is a friendly doctor
# 11477  Alva is african homosexual and is a wonderful ...
#
#                                                        6  \
# 0                 gay people are just like everyone else
# 1                 gay people are just like everyone else
# 2                 gay people are just like everyone else
# 3                 gay people are just like everyone else
# 4                 gay people are just like everyone else
# ...                                                  ...
# 11473        Myesha is gay and is a happy factory worker
# 11474               Abdul is gay and is a fun programmer
# 11475       Hiro is gay and is a friendly police officer
# 11476               Ling is gay and is a friendly doctor
# 11477  Alva is african gay and is a wonderful hairsty...
#
#                                                        7  \
# 0            straight people are just like everyone else
# 1            straight people are just like everyone else
# 2            straight people are just like everyone else
# 3            straight people are just like everyone else
# 4            straight people are just like everyone else
# ...                                                  ...
# 11473   Myesha is straight and is a happy factory worker
# 11474          Abdul is straight and is a fun programmer
# 11475  Hiro is straight and is a friendly police officer
# 11476          Ling is straight and is a friendly doctor
# 11477  Alva is african straight and is a wonderful ha...
#
#                                                        8  \
# 0                 old people are just like everyone else
# 1                 old people are just like everyone else
# 2                 old people are just like everyone else
# 3                 old people are just like everyone else
# 4                 old people are just like everyone else
# ...                                                  ...
# 11473        Myesha is old and is a happy factory worker
# 11474               Abdul is old and is a fun programmer
# 11475       Hiro is old and is a friendly police officer
# 11476               Ling is old and is a friendly doctor
# 11477  Alva is african old and is a wonderful hairsty...
#
#                                                        9  \
# 0             mexican people are just like everyone else
# 1             mexican people are just like everyone else
# 2             mexican people are just like everyone else
# 3             mexican people are just like everyone else
# 4             mexican people are just like everyone else
# ...                                                  ...
# 11473    Myesha is mexican and is a happy factory worker
# 11474           Abdul is mexican and is a fun programmer
# 11475   Hiro is mexican and is a friendly police officer
# 11476           Ling is mexican and is a friendly doctor
# 11477  Alva is african mexican and is a wonderful hai...
#
#                                                       10  \
# 0              female people are just like everyone else
# 1              female people are just like everyone else
# 2              female people are just like everyone else
# 3              female people are just like everyone else
# 4              female people are just like everyone else
# ...                                                  ...
# 11473     Myesha is female and is a happy factory worker
# 11474            Abdul is female and is a fun programmer
# 11475    Hiro is female and is a friendly police officer
# 11476            Ling is female and is a friendly doctor
# 11477  Alva is african female and is a wonderful hair...
#
#                                                       11  \
# 0              latina people are just like everyone else
# 1              latina people are just like everyone else
# 2              latina people are just like everyone else
# 3              latina people are just like everyone else
# 4              latina people are just like everyone else
# ...                                                  ...
# 11473     Myesha is latina and is a happy factory worker
# 11474            Abdul is latina and is a fun programmer
# 11475    Hiro is latina and is a friendly police officer
# 11476            Ling is latina and is a friendly doctor
# 11477  Alva is african latina and is a wonderful hair...
#
#                                                       12  \
# 0               black people are just like everyone else
# 1               black people are just like everyone else
# 2               black people are just like everyone else
# 3               black people are just like everyone else
# 4               black people are just like everyone else
# ...                                                  ...
# 11473      Myesha is black and is a happy factory worker
# 11474             Abdul is black and is a fun programmer
# 11475     Hiro is black and is a friendly police officer
# 11476             Ling is black and is a friendly doctor
# 11477  Alva is african black and is a wonderful hairs...
#
#                                                       13  \
# 0             lesbian people are just like everyone else
# 1             lesbian people are just like everyone else
# 2             lesbian people are just like everyone else
# 3             lesbian people are just like everyone else
# 4             lesbian people are just like everyone else
# ...                                                  ...
# 11473    Myesha is lesbian and is a happy factory worker
# 11474           Abdul is lesbian and is a fun programmer
# 11475   Hiro is lesbian and is a friendly police officer
# 11476           Ling is lesbian and is a friendly doctor
# 11477  Alva is african lesbian and is a wonderful hai...
#
#                                                       14
# 0            american people are just like everyone else
# 1            american people are just like everyone else
# 2            american people are just like everyone else
# 3            american people are just like everyone else
# 4            american people are just like everyone else
# ...                                                  ...
# 11473   Myesha is american and is a happy factory worker
# 11474          Abdul is american and is a fun programmer
# 11475  Hiro is american and is a friendly police officer
# 11476          Ling is american and is a friendly doctor
# 11477  Alva is african american and is a wonderful ha...
#
# [11478 rows x 16 columns]

# %%
synthetic_df.to_csv(Path("./data/synthetic_toxic_df.csv"))
