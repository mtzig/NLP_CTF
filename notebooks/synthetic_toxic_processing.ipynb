# %%
# %cd ..
# Out:
# /Users/teaganjohnson/Desktop/NLP_CTF

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import random

# %%
# civil_df = pd.read_csv("./data/civil_comments.csv")
synthetic_data = pd.read_csv("./data/bias_madlibs_89k.csv")
# train_identities_df = pd.read_csv("./data/test_identities.txt", header=None)
# train_identities_lists = train_identities_df.values.tolist()
test_identities_df = pd.read_csv("./data/test_identities.txt", header=None)
test_identities_list = test_identities_df.values.tolist()

# %%
test_identities = []
for ident in test_identities_list:
    test_identities.append(ident[0])
#train_identities

# %%
print(sum(synthetic_data['Label'] == "NOT_BAD"))
print(synthetic_data.shape)
# Out:
# 44436
# (89483, 2)

# %%
sentences = []
a = []
toxicity = []

for row_index in tqdm(range(len(synthetic_data))):
    comment_text = synthetic_data.iloc[row_index]['Text'].split()
    if synthetic_data.iloc[row_index]['Label'] == "BAD" and len(set(test_identities).intersection(comment_text)) != 0:
        identity = str(set(test_identities).intersection(comment_text).pop())
        sentences.append(synthetic_data.iloc[row_index]['Text'])
        toxicity.append(0)
        cur_a = []
        
        for diff_identity in test_identities:
            cur_a.append(synthetic_data.at[row_index, "Text"].replace(identity, diff_identity))
        a.append(cur_a)
# print(sentences)
# print(toxicity)
# print(a)
# Out:
# 100%|██████████| 89483/89483 [00:15<00:00, 5756.03it/s]

# %%
synthetic_raw = pd.DataFrame(list(zip(*a)))
synthetic_df = synthetic_raw.T

synthetic_df.insert(0, column='comment_text', value=sentences)

synthetic_df
# Out:
#                                             comment_text  \
# 0       latina people are gross and universally terrible
# 1      lesbian people are gross and universally terrible
# 2      paralyzed people are gross and universally ter...
# 3        black people are gross and universally terrible
# 4      protestant people are gross and universally te...
# ...                                                  ...
# 11678          Ying is gay and is a disgusting machinist
# 11679  Sulin is american and is a idiotic computer pr...
# 11680       Elizabeth is latina and is a gross secretary
# 11681           서윤 is lesbian and is a idiotic architect
# 11682     Sara is protestant and is a disgusting janitor
#
#                                                        0  \
# 0      african american people are gross and universa...
# 1      african american people are gross and universa...
# 2      african american people are gross and universa...
# 3      african american people are gross and universa...
# 4      african american people are gross and universa...
# ...                                                  ...
# 11678  Ying is african american and is a disgusting m...
# 11679  Sulin is african american and is a idiotic com...
# 11680  Elizabeth is african american and is a gross s...
# 11681  서윤 is african american and is a idiotic architect
# 11682  Sara is african american and is a disgusting j...
#
#                                                        1  \
# 0      middle aged people are gross and universally t...
# 1      middle aged people are gross and universally t...
# 2      middle aged people are gross and universally t...
# 3      middle aged people are gross and universally t...
# 4      middle aged people are gross and universally t...
# ...                                                  ...
# 11678  Ying is middle aged and is a disgusting machinist
# 11679  Sulin is middle aged and is a idiotic computer...
# 11680  Elizabeth is middle aged and is a gross secretary
# 11681       서윤 is middle aged and is a idiotic architect
# 11682    Sara is middle aged and is a disgusting janitor
#
#                                                        2  \
# 0      middle eastern people are gross and universall...
# 1      middle eastern people are gross and universall...
# 2      middle eastern people are gross and universall...
